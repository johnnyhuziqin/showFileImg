# %% [markdown]
# ### 图片列表

# %%
import matplotlib.pyplot as plt
# %matplotlib inline 
from PIL import Image


def getImgSize(path):
    img = Image.open(path)
    #print("img size:%rx%d"%(img.size[0],img.size[1]))
    return img.size

picPath = "/home/huziqin/work/gitwork/8388/application/customer_app/siba/target/siba/PA/Resource/home/Key_001_carplay_s.png"
#im = Image.open(picPath)
im = plt.imread(picPath)
imgSize = getImgSize(picPath)
fig, ax = plt.subplots()
plt.figure(figsize=(1,1))
ax.imshow(im)
ax.set_title("sample")
ax.set_xlabel('size:{}'.format(imgSize))
# Out:
# Text(0.5,0,u'size:(147, 325)')

# %%
import os  
    
def GetFileList(FindPath,FlagStr=[]):  
    ''''' 
    #获取目录中指定的文件名 
    #>>>FlagStr=['F','EMS','txt'] #要求文件名称中包含这些字符 
    #>>>FileList=GetFileList(FindPath,FlagStr) # 
    '''  
    FileList=[]  
    FileNames=os.listdir(FindPath)  
    #print(FileNames)
    if (len(FileNames)>0):  
       for fn in FileNames:  
           if (len(FlagStr)>0):  
               #返回指定类型的文件名  
               if (IsSubString(FlagStr,fn)):  
                    fullfilename=os.path.join(FindPath,fn)  
                    FileList.append(fullfilename)  
           else:  
               #默认直接返回所有文件名  
                fullfilename=os.path.join(FindPath,fn)  
                FileList.append(fullfilename)  
  
    #对文件名排序  
    if (len(FileList)>0):  
        FileList.sort()  
  
    return FileList  

#picPath = "/home/huziqin/work/gitwork/8388/application/customer_app/siba/target/siba/PA/Resource/home/"
#fileList = GetFileList(picPath,[])

#pathSplit = os.path.split(fileList[0])
#print("fileName:%s"%(pathSplit[1]))

# %%
def  showFileImage(fileList):
    num_pic = len(fileList)
    x_id = 0
    y_id = 0
    num_x = 4
    num_y = (num_pic+num_x-1)/num_x

    fig, axs = plt.subplots(num_y, num_x,figsize=(20,num_pic*1.5))
    #fig, axs = plt.subplots(num_y, num_x)
    #plt.suptitle('pic list',fontsize = 20)
    #plt.figure(figsize=(20,60))
    
#    plt.autoscale(enable=False, axis=u'x',tight=False)
#    fig.autoscale(enable=False, axis=u'x',tight=False)
    for pic_id in range(num_pic):
        if x_id >= num_x:
            x_id = 0
            y_id = y_id + 1
        axs_n = axs[y_id,x_id] 
        path = fileList[pic_id]
        image = plt.imread(path)
        axs_n.imshow(image)
        #axs_n.axis('off')
        fileName = os.path.split(path)[1]
        axs_n.set_title(fileName,fontsize=10)
        imgSize = getImgSize(path)
        axs_n.set_xlabel('size:{}'.format(imgSize))
        x_id = x_id + 1

def showDirPics(path):
    fileListInDir = GetFileList(path,[])
    print("total files:%d"%(len(fileListInDir)))
    showFileImage(fileListInDir) 
    
#picPath1 = "/home/huziqin/work/gitwork/8388/application/customer_app/siba/target/siba/PA/Resource/home/"    
#showDirPics(picPath2)

# %%
print(plt.style.available)     # 查看所有的styles
plt.style.use('ggplot')        # 选择需要的style
# Out:
# [u'seaborn-darkgrid', u'Solarize_Light2', u'seaborn-notebook', u'classic', u'seaborn-ticks', u'grayscale', u'bmh', u'seaborn-talk', u'dark_background', u'ggplot', u'fivethirtyeight', u'_classic_test', u'seaborn-colorblind', u'seaborn-deep', u'seaborn-whitegrid', u'seaborn-bright', u'seaborn-poster', u'seaborn-muted', u'seaborn-paper', u'seaborn-white', u'fast', u'seaborn-pastel', u'seaborn-dark', u'seaborn', u'seaborn-dark-palette']

# %%
#picPath1 = "/home/huziqin/work/gitwork/8388/application/customer_app/siba/target/siba/PA/Resource/home/"    
picPath1 = "/home/huziqin/work/gitwork/8388/application/customer_app/siba/target/siba/X2/Resource/tuner"  
showDirPics(picPath1)
# Out:
# total files:167

# %%
#picPath2 = "/home/huziqin/work/gitwork/8388/application/customer_app/siba/target/siba/PA/Resource/tuner/"    
#showDirPics(picPath2)
